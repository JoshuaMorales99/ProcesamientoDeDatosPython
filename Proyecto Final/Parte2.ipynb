# %% [markdown]
# # PREYECTO FINAL INTEGRADOR - PARTE 2

# %% [markdown]
# ## 🔶 Consigna

# %% [markdown]
# Realizar una ingesta de datos de un archivo formato .csv utilizando la librería de Pandas. Para este apartado, deberás poder ingestar un archivo en Jupyter Notebook en un formato de tipo .csv.
#
# Resulta importante aclarar que, la elección del archivo queda a criterio propio, sin embargo a continuación se proporciona un link de interés para la descarga gratuita de datasets.
#
# Enlace: https://www.kaggle.com/datasets
#
# > Importante: en caso de no disponer de una cuenta en Kaggle, será requerido realizar el registro correspondiente en la página.

# %% [markdown]
# ## 🔶 Propuesta

# %% [markdown]
# Para esta parte, se utilizará un DataSet que trata sobre el **desperdicio alimenticio** (Food Waste).
#
# El mismo fue extraido del siguiente enlace: https://www.kaggle.com/datasets/joebeachcapital/food-waste.

# %% [markdown]
# ### Informacion sobre el DataSet.

# %%
# Importamos las librerias necesarias.
import pandas as pd
import matplotlib.pyplot as plt

# Importamos el DataSet.
df = pd.read_csv("C:/Users/Joshua/Desktop/Archivos y Anotaciones/Mis Documentos/Educacion/Argentina Programa/Procesamiento de Datos con Python/Proyecto Final/Food Waste data and research.csv", sep = ',')

# %%
# Mostrar las primeras 5 lineas.
df.head()
# Out:
#        Country  combined figures (kg/capita/year)  \
# 0  Afghanistan                                126
# 1      Albania                                127
# 2      Algeria                                135
# 3      Andorra                                123
# 4       Angola                                144
#
#    Household estimate (kg/capita/year)  Household estimate (tonnes/year)  \
# 0                                   82                           3109153
# 1                                   83                            238492
# 2                                   91                           3918529
# 3                                   84                              6497
# 4                                  100                           3169523
#
#    Retail estimate (kg/capita/year)  Retail estimate (tonnes/year)  \
# 0                                16                         594982
# 1                                16                          45058
# ...

# %%
# Mostrar las ultimas 5 lineas.
df.tail()
# Out:
#                         Country  combined figures (kg/capita/year)  \
# 209  Venezuela (Boliv. Rep. of)                                116
# 210                    Viet Nam                                120
# 211                       Yemen                                148
# 212                      Zambia                                122
# 213                    Zimbabwe                                144
#
#      Household estimate (kg/capita/year)  Household estimate (tonnes/year)  \
# 209                                   72                           2065461
# 210                                   76                           7346717
# 211                                  104                           3026946
# 212                                   78                           1391729
# 213                                  100                           1458564
#
#      Retail estimate (kg/capita/year)  Retail estimate (tonnes/year)  \
# ...

# %%
# Mostrar las dimensiones del DataSet.
print(df.shape)
# Out:
# (214, 12)

# %% [markdown]
# > Posee 214 filas y 12 columnas.

# %%
# Obtener la totalidad de registros por columna.
df.count()
# Out:
# Country                                   214
# combined figures (kg/capita/year)         214
# Household estimate (kg/capita/year)       214
# Household estimate (tonnes/year)          214
# Retail estimate (kg/capita/year)          214
# Retail estimate (tonnes/year)             214
# Food service estimate (kg/capita/year)    214
# Food service estimate (tonnes/year)       214
# Confidence in estimate                    214
# M49 code                                  214
# Region                                    214
# Source                                    214
# dtype: int64

# %% [markdown]
# > Se puede ver que no presenta valores missings

# %%
# Para estar mas seguros, verificamos la cantidad de valores missings que tenermos por columna.
print(df.isna().sum())
# Out:
# Country                                   0
# combined figures (kg/capita/year)         0
# Household estimate (kg/capita/year)       0
# Household estimate (tonnes/year)          0
# Retail estimate (kg/capita/year)          0
# Retail estimate (tonnes/year)             0
# Food service estimate (kg/capita/year)    0
# Food service estimate (tonnes/year)       0
# Confidence in estimate                    0
# M49 code                                  0
# Region                                    0
# Source                                    0
# dtype: int64

# %%
# Mostrar los tipos de dato de cada columna.
df.dtypes
# Out:
# Country                                   object
# combined figures (kg/capita/year)          int64
# Household estimate (kg/capita/year)        int64
# Household estimate (tonnes/year)           int64
# Retail estimate (kg/capita/year)           int64
# Retail estimate (tonnes/year)              int64
# Food service estimate (kg/capita/year)     int64
# Food service estimate (tonnes/year)        int64
# Confidence in estimate                    object
# M49 code                                   int64
# Region                                    object
# Source                                    object
# dtype: object

# %%
# Obtener el tipo de estructura del DataSet.
type(df)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# > El tipo de estructura del DataSet es: DataFrame.

# %%
# Obtener la lista de las columnas.
print(df.columns)
# Out:
# Index(['Country', 'combined figures (kg/capita/year)',
#        'Household estimate (kg/capita/year)',
#        'Household estimate (tonnes/year)', 'Retail estimate (kg/capita/year)',
#        'Retail estimate (tonnes/year)',
#        'Food service estimate (kg/capita/year)',
#        'Food service estimate (tonnes/year)', 'Confidence in estimate',
#        'M49 code', 'Region', 'Source'],
#       dtype='object')

# %%
# Obtener informacion mas detallada.
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 214 entries, 0 to 213
# Data columns (total 12 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   Country                                 214 non-null    object
#  1   combined figures (kg/capita/year)       214 non-null    int64
#  2   Household estimate (kg/capita/year)     214 non-null    int64
#  3   Household estimate (tonnes/year)        214 non-null    int64
#  4   Retail estimate (kg/capita/year)        214 non-null    int64
#  5   Retail estimate (tonnes/year)           214 non-null    int64
#  6   Food service estimate (kg/capita/year)  214 non-null    int64
#  7   Food service estimate (tonnes/year)     214 non-null    int64
#  8   Confidence in estimate                  214 non-null    object
#  9   M49 code                                214 non-null    int64
# ...

# %% [markdown]
# ### Transformaciones en el DataSet.

# %% [markdown]
# Para este apartado, realizaremos algunas consultas y graficos.

# %%
# Mostrar los registros que tengan 'High Confidence'.
df[df['Confidence in estimate'] == "High Confidence"]
# Out:
#                       Country  combined figures (kg/capita/year)  \
# 9                   Australia                                133
# 10                    Austria                                 76
# 54                    Denmark                                132
# 74                    Germany                                102
# 96                      Italy                                 97
# 136               New Zealand                                 90
# 167              Saudi Arabia                                151
# 185                    Sweden                                112
# 202            United Kingdom                                 98
# 204  United States of America                                139
#
#      Household estimate (kg/capita/year)  Household estimate (tonnes/year)  \
# 9                                    102                           2563110
# 10                                    39                            349249
# ...

# %%
# Almacenamos el listado de los 10 paises con mayor desperdicio de comida del DataSet.
Top10HighestFoodWaste = df.nlargest(10, 'combined figures (kg/capita/year)')

# Mostrar el listado de los top 10 paises con mayor desperdicio de comida del DataSet.
Top10HighestFoodWaste
# Out:
#                      Country  combined figures (kg/capita/year)  \
# 116                 Malaysia                                260
# 139                  Nigeria                                233
# 159                   Rwanda                                208
# 95                    Israel                                178
# 77                    Greece                                175
# 13                   Bahrain                                171
# 119                    Malta                                168
# 92                      Iraq                                164
# 203  United Rep. of Tanzania                                163
# 167             Saudi Arabia                                151
#
#      Household estimate (kg/capita/year)  Household estimate (tonnes/year)  \
# 116                                   91                           2921577
# 139                                  189                          37941470
# ...

# %%
# Importamos la libreria para hacer graficos en Python.
import seaborn as sns

# Creamos el grafico y lo mostramos.
sns.barplot(x = Top10HighestFoodWaste['combined figures (kg/capita/year)'], y = Top10HighestFoodWaste['Country'])
plt.title("Top 10 Paises con mayor desperdicio alimenticio")
plt.show()

# %%
# Almacenamos el listado de los 10 paises con menor desperdicio de comida del DataSet.
Top10LessFoodWaste = df.nsmallest(10, 'combined figures (kg/capita/year)')

# Mostrar el listado de los top 10 paises con menor desperdicio de comida del DataSet.
Top10LessFoodWaste
# Out:
#                 Country  combined figures (kg/capita/year)  \
# 175            Slovenia                                 61
# 158  Russian Federation                                 75
# 10              Austria                                 76
# 17              Belgium                                 80
# 14           Bangladesh                                 84
# 178        South Africa                                 84
# 134         Netherlands                                 87
# 98                Japan                                 88
# 136         New Zealand                                 90
# 89                India                                 94
#
#      Household estimate (kg/capita/year)  Household estimate (tonnes/year)  \
# 175                                   34                             71107
# 158                                   33                           4868564
# 10                                    39                            349249
# ...

# %%
# Creamos el grafico y lo mostramos.
sns.barplot(x = Top10LessFoodWaste['combined figures (kg/capita/year)'], y = Top10LessFoodWaste['Country'])
plt.title("Top 10 Paises con menor desperdicio alimenticio")
plt.show()
